# %% [markdown]
# <a href="https://colab.research.google.com/github/xpecon00/MPA-MLF/blob/main/Lab7/lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # MPA-MLF, Lab 7 - Convolutional Neural Network

# %% [markdown]
# ## Exercise - Hand-written digits recognition

# %% [markdown]
# Create CNN which will process and recognize handwritten digits. For this purposes please use the MNIST database (Modified National Institute of Standards and Technology database) which is a large database of handwritten digits that is commonly used for training various image processing systems.
#
# The datasample of the MNIST datasets can be see in the following picture

# %% [markdown]
# ### Task description

# %% [markdown]
# In the terms of machine learning, the Hand-written digits recognition can be threated as a multi-class classification problem. This is very important knowledge to structure our model in the correct way (Especially the output-layer, including the number of neurons and activations function and the overall loss function and classification metrics)

# %% [markdown]
# ### 0. Import libraries

# %% [markdown]
# Import the all necessary libraries, you can get inspired by the previous exercises. You can improst the libraries gradually, when do you progressing with the task

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.datasets import mnist
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score

###################################
# Write your own code here #

from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D
from keras.optimizers import SGD, Adagrad, Adam, AdamW
from keras.datasets import cifar10
from keras.utils import to_categorical
import cv2

###################################
font = {'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

# %% [markdown]
# ### 1. Dataset

# %% [markdown]
# #### 1.1 Load Dataset

# %% [markdown]
# You can load the dataset using the following code

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape
X_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# #### 1.2 Dataset examination

# %% [markdown]
# Using the following code, display random images,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels = y_data[selected_ind]
  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img, cmap="gray")

  for id_label, label in enumerate(selected_labels):
    plt.text(14 + 28*id_label, 28*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %% [markdown]
# Examine the dataset. Answer for yourself the following questions:
#
# - What kind of data occurs in our dataset?
# - How many data samples do we have in train and test datasets?
# - How many colour channels does the input variable have?
# - What is the size of the input images?
# - What is the necessary preprocessing of the input data X?
# - How many classes do we have in target varoable?
# - What is the necessary preprocessing of target variable y?

# %% [markdown]
# #### 1.3 Dataset preprocessing

# %% [markdown]
# Perform the necessary data preprocessing. The best way to preprocess the data would be one hot encoding for the target variable and normalization for the input variable (using min-max or z-score normalization)

# %%
###################################
# Write your own code here #
X_train_exp = np.expand_dims(X_train, -1)
X_train_scaled = X_train_exp.astype('float32') / 255.0
y_train_encoded = to_categorical(y_train, num_classes=10)
###################################

# %% [markdown]
# ### 2. Build the model

# %% [markdown]
# In this section, your task will be to define the model architecture. The intial structure can be defined as follows:
#
# Input_layer -> Convolutional_layer(kernel_size=(3,3), no_channels=32) -> Maxpooling_layer(kernel_size=(2, 2)) -> Flatten_layer -> Dense_layer (num_classes)

# %% [markdown]
# #### 2.1 Define the model structure

# %%
model = Sequential()
###################################
# Write your own code here #
model.add(Conv2D(16, (5, 5), activation='relu', input_shape=(28, 28, 1))) #(26, 26,64) #(28, 28, 1)
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
###################################

# %% [markdown]
# #### 2.2 Compile the model

# %% [markdown]
# Build the model, use the relevant metrics, optimizer and loss function. While choosing the metrics and loss function, consider fact that we are are trying to solve the multiclass classification problem

# %%
###################################
# Write your own code here #
loss = 'categorical_crossentropy'
metrics = 'accuracy'
learning_rate = 0.001
optimizer = AdamW(learning_rate = learning_rate)
model.compile(loss=loss, optimizer=optimizer, metrics=[metrics])
###################################
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 16)        416
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 32)                25632
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 31018 (121.16 KB)
# Trainable params: 31018 (121.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 3. Training stage

# %% [markdown]
# #### 3.1 Model training

# %% [markdown]
# train your model, define the relevant hyperparameters (no. epochs, batch_size), use 20p of the training data for validation

# %%
###################################
# Write your own code here #
history = model.fit(X_train_scaled, y_train_encoded, epochs=20, batch_size=32, validation_split = 0.2)
###################################
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 13s 5ms/step - loss: 0.5740 - accuracy: 0.8052 - val_loss: 0.1019 - val_accuracy: 0.9707
# Epoch 2/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2976 - accuracy: 0.8975 - val_loss: 0.0829 - val_accuracy: 0.9745
# Epoch 3/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2418 - accuracy: 0.9150 - val_loss: 0.0602 - val_accuracy: 0.9844
# Epoch 4/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2146 - accuracy: 0.9251 - val_loss: 0.0563 - val_accuracy: 0.9852
# Epoch 5/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1865 - accuracy: 0.9362 - val_loss: 0.0549 - val_accuracy: 0.9858
# Epoch 6/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1769 - accuracy: 0.9384 - val_loss: 0.0525 - val_accuracy: 0.9875
# Epoch 7/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1694 - accuracy: 0.9407 - val_loss: 0.0500 - val_accuracy: 0.9877
# Epoch 8/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1579 - accuracy: 0.9446 - val_loss: 0.0538 - val_accuracy: 0.9877
# Epoch 9/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1496 - accuracy: 0.9475 - val_loss: 0.0501 - val_accuracy: 0.9881
# Epoch 10/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1435 - accuracy: 0.9492 - val_loss: 0.0457 - val_accuracy: 0.9892
# Epoch 11/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1357 - accuracy: 0.9512 - val_loss: 0.0454 - val_accuracy: 0.9892
# Epoch 12/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1348 - accuracy: 0.9514 - val_loss: 0.0533 - val_accuracy: 0.9873
# Epoch 13/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1300 - accuracy: 0.9546 - val_loss: 0.0448 - val_accuracy: 0.9894
# Epoch 14/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1210 - accuracy: 0.9567 - val_loss: 0.0440 - val_accuracy: 0.9906
# Epoch 15/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1200 - accuracy: 0.9569 - val_loss: 0.0436 - val_accuracy: 0.9897
# Epoch 16/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1178 - accuracy: 0.9572 - val_loss: 0.0438 - val_accuracy: 0.9900
# Epoch 17/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1127 - accuracy: 0.9604 - val_loss: 0.0493 - val_accuracy: 0.9902
# Epoch 18/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1145 - accuracy: 0.9598 - val_loss: 0.0424 - val_accuracy: 0.9905
# Epoch 19/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1058 - accuracy: 0.9628 - val_loss: 0.0456 - val_accuracy: 0.9892
# Epoch 20/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1080 - accuracy: 0.9618 - val_loss: 0.0480 - val_accuracy: 0.9905

# %% [markdown]
# #### 3.1 Model Evaluation on validation data

# %% [markdown]
# Plot the development of the training and validation loss, and training and validation metrics.

# %%
X_test_exp = np.expand_dims(X_test, -1)
X_test_preprocessed = X_test_exp.astype('float32') / 255.0
y_test_encoded = to_categorical(y_test, num_classes=10)

# %%
###################################
# Write your own code here #
score = model.evaluate(X_test_preprocessed, y_test_encoded, verbose=0)

print('Test loss:', score[0])
print(f'Test accuracy: {score[1]*100} %')

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

###################################
# Out:
# Test loss: 0.0329103097319603
# Test accuracy: 99.14000034332275 %

# %% [markdown]
# ### 4. Model evaluation

# %% [markdown]
# Evaluate the model on the testing dataset using the relevant metrics. Use the confusion metrics as the one of the metrics.

# %%
predictions = np.round(model.predict(X_test_preprocessed, verbose=0))

# Compute confusion matrices for each number
cm = multilabel_confusion_matrix(y_test_encoded, predictions)

# Display confusion matrices for each number
for i in range(10):
    disp = ConfusionMatrixDisplay(cm[i], display_labels=['else', i])
    disp.plot()

# %% [markdown]
# ### 5. Hyperparameter tunning and regularization techniques

# %% [markdown]
# When your code is ready and fully functional, try several changes in the hyperparameters and see how they influence the testing metrics. Try changes in the network structure. You can also try adding regularization techniques such as L1, L2, and Dropout. Based on the development of training and validation loss, try to identify overfitting and avoid it
